# %%
import xarray as xr
import matplotlib.pyplot as plt

ds = xr.open_dataset("./output-tracer-release_2025-02-15.nc")
ds
# Out:
# /glade/derecho/scratch/ntheunissen/tmp/ipykernel_50518/4187895343.py:4: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_dataset("./output-tracer-release_2025-02-15.nc")
# <xarray.Dataset> Size: 10MB
# Dimensions:  (zC: 1, zF: 1, xC: 100, yF: 100, xF: 100, yC: 100, time: 49)
# Coordinates:
#   * zC       (zC) float32 4B -5.0
#   * zF       (zF) float32 4B -10.0
#   * xC       (xC) float32 400B 500.0 1.5e+03 2.5e+03 ... 9.85e+04 9.95e+04
#   * yF       (yF) float32 400B 0.0 1e+03 2e+03 3e+03 ... 9.7e+04 9.8e+04 9.9e+04
#   * xF       (xF) float32 400B 0.0 1e+03 2e+03 3e+03 ... 9.7e+04 9.8e+04 9.9e+04
#   * yC       (yC) float32 400B 500.0 1.5e+03 2.5e+03 ... 9.85e+04 9.95e+04
#   * time     (time) timedelta64[ns] 392B 00:00:00 01:00:00 ... 2 days 00:00:00
# Data variables:
# ...

# %%
plt.pcolor(ds["c"][-1,0,:,:])
